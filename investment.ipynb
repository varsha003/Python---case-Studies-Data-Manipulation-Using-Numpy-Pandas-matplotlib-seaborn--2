# %% [markdown]
# #### Case Study 1 :
# Dataset Description: The file consists of start-ups investment details.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Read the given comma separated values as dataframe (investments.csv)

# %%
df= pd.read_csv("investments.csv")
df
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                 |Publishing|Education|           Publishing
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# 4                          |Tourism|Entertainment|Games|              Tourism
# ...                                                  ...                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#       funding_total_usd     status country_code state_code         region  \
# 0             17,50,000   acquired          USA         NY  New York City
# 1             40,00,000  operating          USA         CA    Los Angeles
# 2                40,000  operating          EST        NaN        Tallinn
# 3             15,00,000  operating          GBR        NaN         London
# 4                60,000  operating          USA         TX         Dallas
# ...                 ...        ...          ...        ...            ...
# 49433          3,20,000  operating          GBR        NaN         London
# 49434         15,87,301  operating          CHN        NaN        Beijing
# 49435            97,398  operating          HRV        NaN          Split
# 49436         93,00,000  operating          NaN        NaN            NaN
# 49437       4,50,00,000  operating          USA         NY  New York City
#
#               city  funding_rounds  founded_year  debt_financing  grant
# 0         New York               1        2012.0               0      0
# 1      Los Angeles               2           NaN               0      0
# 2          Tallinn               1        2012.0               0      0
# 3           London               1        2011.0               0      0
# 4       Fort Worth               2        2014.0               0      0
# ...            ...             ...           ...             ...    ...
# 49433       London               1        2013.0               0      0
# 49434      Beijing               1           NaN               0      0
# 49435        Split               5        2012.0               0      0
# 49436          NaN               1           NaN               0      0
# 49437     New York               4        1999.0        17000000      0
#
# [49438 rows x 14 columns]

# %% [markdown]
# 2. List out all column names

# %%
df.columns
print(list(df))
df.keys()
# Out:
# ['name', 'homepage_url', 'category_list', 'market', 'funding_total_usd', 'status', 'country_code', 'state_code', 'region', 'city', 'funding_rounds', 'founded_year', 'debt_financing', 'grant']
# Index(['name', 'homepage_url', 'category_list', 'market', 'funding_total_usd',
#        'status', 'country_code', 'state_code', 'region', 'city',
#        'funding_rounds', 'founded_year', 'debt_financing', 'grant'],
#       dtype='object')

# %% [markdown]
# 3.Create a dataframe with numerical columns.

# %%
df.select_dtypes(include='number')
# Out:
#        funding_rounds  founded_year  debt_financing  grant
# 0                   1        2012.0               0      0
# 1                   2           NaN               0      0
# 2                   1        2012.0               0      0
# 3                   1        2011.0               0      0
# 4                   2        2014.0               0      0
# ...               ...           ...             ...    ...
# 49433               1        2013.0               0      0
# 49434               1           NaN               0      0
# 49435               5        2012.0               0      0
# 49436               1           NaN               0      0
# 49437               4        1999.0        17000000      0
#
# [49438 rows x 4 columns]

# %% [markdown]
# 4.Create a dataframe with categorical columns.

# %%
df.select_dtypes(include='object')
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                 |Publishing|Education|           Publishing
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# 4                          |Tourism|Entertainment|Games|              Tourism
# ...                                                  ...                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#       funding_total_usd     status country_code state_code         region  \
# 0             17,50,000   acquired          USA         NY  New York City
# 1             40,00,000  operating          USA         CA    Los Angeles
# 2                40,000  operating          EST        NaN        Tallinn
# 3             15,00,000  operating          GBR        NaN         London
# 4                60,000  operating          USA         TX         Dallas
# ...                 ...        ...          ...        ...            ...
# 49433          3,20,000  operating          GBR        NaN         London
# 49434         15,87,301  operating          CHN        NaN        Beijing
# 49435            97,398  operating          HRV        NaN          Split
# 49436         93,00,000  operating          NaN        NaN            NaN
# 49437       4,50,00,000  operating          USA         NY  New York City
#
#               city
# 0         New York
# 1      Los Angeles
# 2          Tallinn
# 3           London
# 4       Fort Worth
# ...            ...
# 49433       London
# 49434      Beijing
# 49435        Split
# 49436          NaN
# 49437     New York
#
# [49438 rows x 10 columns]

# %% [markdown]
# 5.	Get a summary on the data and draw inferences if any.

# %%
df.describe()
# Out:
#        funding_rounds  founded_year  debt_financing         grant
# count    49438.000000  38482.000000    4.943800e+04  4.943800e+04
# mean         1.696205   2007.359129    1.888157e+06  1.628453e+05
# std          1.294213      7.579203    1.382046e+08  5.612088e+06
# min          1.000000   1902.000000    0.000000e+00  0.000000e+00
# 25%          1.000000   2006.000000    0.000000e+00  0.000000e+00
# 50%          1.000000   2010.000000    0.000000e+00  0.000000e+00
# 75%          2.000000   2012.000000    0.000000e+00  0.000000e+00
# max         18.000000   2014.000000    3.007950e+10  7.505000e+08

# %%
df.shape
# Out:
# (49438, 20)

# %% [markdown]
# 6.	Display duplicate rows.

# %%
df.duplicated().sum()  ##in rows
# Out:
# 0

# %%
#### find out duplicate records at name,category_list, market
df.duplicated(subset=['name','category_list','market']).sum()
# Out:
# 3

# %%
### displaying the details of the records having duplicates
df[df.duplicated(subset=['name','category_list','market'])]
# Out:
#                     name            homepage_url    category_list  \
# 4150   AYOXXA Biosystems  http://www.ayoxxa.com/  |Biotechnology|
# 24028       Lightex Ltd.                     NaN              NaN
# 36084            Roadmap                     NaN              NaN
#
#               market funding_total_usd     status country_code state_code  \
# 4150   Biotechnology       1,40,81,347  operating          DEU        NaN
# 24028            NaN          5,00,000  operating          NaN        NaN
# 36084            NaN                 -  operating          USA         NC
#
#           region       city  funding_rounds  founded_year  debt_financing  \
# 4150     Cologne       Köln               1        2010.0               0
# 24028        NaN        NaN               1           NaN               0
# 36084  Charlotte  Charlotte               1        2011.0               0
#
#        grant
# 4150       0
# 24028      0
# 36084      0

# %%
f = (df.name == 'Roadmap') & (df.category_list.isna()) & (df.market.isna()) 
df[f]
# Out:
#           name                      homepage_url category_list market  \
# 36083  Roadmap  http://www.roadmapsystems.co.uk/           NaN    NaN
# 36084  Roadmap                               NaN           NaN    NaN
#
#       funding_total_usd     status country_code state_code     region  \
# 36083                 -  operating          GBR        NaN     London
# 36084                 -  operating          USA         NC  Charlotte
#
#             city  funding_rounds  founded_year  debt_financing  grant
# 36083  Cambridge               1           NaN               0      0
# 36084  Charlotte               1        2011.0               0      0

# %%
f= df.name=='AYOXXA Biosystems'
df[f]
# Out:
#                    name            homepage_url    category_list  \
# 4149  AYOXXA Biosystems       http://ayoxxa.com  |Biotechnology|
# 4150  AYOXXA Biosystems  http://www.ayoxxa.com/  |Biotechnology|
#
#              market funding_total_usd     status country_code state_code  \
# 4149  Biotechnology       1,21,45,503  operating          DEU        NaN
# 4150  Biotechnology       1,40,81,347  operating          DEU        NaN
#
#        region     city  funding_rounds  founded_year  debt_financing  grant
# 4149  Cologne  Cologne               1        2010.0               0      0
# 4150  Cologne     Köln               1        2010.0               0      0

# %% [markdown]
# 7.	For each column find out the percentage of missing values.

# %%
count = df.isnull().sum()
per = df.isnull().sum()/df.shape[0]*100
pd.concat([pd.DataFrame(count, columns=['count']),pd.DataFrame(per, columns=['percentage']) ], axis = 1).sort_values('percentage')
# Out:
#                    count  percentage
# funding_total_usd      0    0.000000
# funding_rounds         0    0.000000
# debt_financing         0    0.000000
# grant                  0    0.000000
# name                   1    0.002023
# status              1314    2.657875
# homepage_url        3449    6.976415
# category_list       3961    8.012056
# market              3968    8.026215
# country_code        5273   10.665885
# region              5273   10.665885
# city                6116   12.371051
# founded_year       10956   22.161091
# state_code         19277   38.992273

# %%
df.city.isna().sum()
# Out:
# 6116

# %% [markdown]
# 8.	Find count of ‘name’ in each ‘country_code’.

# %%
df.groupby('country_code')['name'].count()
# Out:
# country_code
# ALB        1
# ARE       66
# ARG      149
# ARM        2
# AUS      314
#        ...
# USA    28793
# UZB        1
# VNM       21
# ZAF       52
# ZWE        1
# Name: name, Length: 115, dtype: int64

# %% [markdown]
# 9.	What is the percentage of the companies which have status ‘acquired’ ‘operating’?

# %%
df[df.status.isin(['operating','acquired'])].shape[0]/len(df)*100
# Out:
# 92.07694486022898

# %% [markdown]
# 10.	What is the percentage of the companies which have status ‘acquired’ acquired?

# %%
df[df.status.isin(['acquired'])].shape[0]/len(df)*100
# Out:
# 7.467939641571261

# %% [markdown]
# 11.	Filter records having missing values in column ‘year_founded’.

# %%
df[df.founded_year.isnull()].shape
# Out:
# (10956, 14)

# %% [markdown]
# 12.	Create a column ‘category_list_count’ having count of category lists.

# %%
df['category_list_count'] = df[['category_list']].applymap(lambda x : 0 if (len(str(x).split('|')) - 2) < 0 else len(str(x).split('|')) - 2)
df.loc[:,['category_list','category_list_count']].head()
# Out:
#                                        category_list  category_list_count
# 0         |Entertainment|Politics|Social Media|News|                    4
# 1                                            |Games|                    1
# 2                             |Publishing|Education|                    2
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...                   10
# 4                      |Tourism|Entertainment|Games|                    3

# %% [markdown]
# 13.	Find average funding_total_usd for each country_code.

# %%
df.funding_total_usd = np.where(df.funding_total_usd == '-', '0' , df.funding_total_usd)
df.funding_total_usd = df.funding_total_usd.apply(lambda x : str(x).replace(',',''))
df.funding_total_usd = df.funding_total_usd.astype(float)
df.groupby('country_code')['funding_total_usd'].mean()
# Out:
# country_code
# ALB    0.000000e+00
# ARE    9.832352e+06
# ARG    1.787353e+06
# ARM    1.340649e+07
# AUS    8.276922e+06
#            ...
# USA    1.612353e+07
# UZB    9.000000e+04
# VNM    1.023431e+07
# ZAF    1.243687e+07
# ZWE    1.000000e+07
# Name: funding_total_usd, Length: 115, dtype: float64

# %% [markdown]
# 14.	Find total funding_total_usd for each country_code.

# %%
df.groupby('country_code')['funding_total_usd'].sum()
# Out:
# country_code
# ALB    0.000000e+00
# ARE    6.489352e+08
# ARG    2.663157e+08
# ARM    2.681298e+07
# AUS    2.598953e+09
#            ...
# USA    4.642448e+11
# UZB    9.000000e+04
# VNM    2.149205e+08
# ZAF    6.467170e+08
# ZWE    1.000000e+07
# Name: funding_total_usd, Length: 115, dtype: float64

# %% [markdown]
# 15.	Find average funding_total_usd in each country_code and region.

# %%
df.groupby(['country_code','region'])['funding_total_usd'].mean()
# Out:
# country_code  region
# ALB           Tirana          0.000000e+00
# ARE           Abu Dhabi       1.562500e+07
#               Dubai           9.651332e+06
# ARG           ARG - Other     3.049519e+05
#               Buenos Aires    1.760614e+06
#                                   ...
# ZAF           Cape Town       1.559547e+07
#               Durban          0.000000e+00
#               Johannesburg    6.091429e+06
#               ZAF - Other     0.000000e+00
# ZWE           Harare          1.000000e+07
# Name: funding_total_usd, Length: 1096, dtype: float64

# %% [markdown]
# 16.	How many companies have got just 1 round of funding?

# %%
df.columns
df[df.funding_rounds==1]['name'].count()
# Out:
# 32038

# %% [markdown]
# 17.	Perform mapping on status column; acquired -> A, operating -> O and closed -> C.

# %%
df['status_E'] = df.status.apply(lambda x: 'A' if x == 'acquired' else 'O' if x == 'operating' else 'C' if x == 'closed' else 'U')
df.loc[:,['status','status_E']].head()
# Out:
#       status status_E
# 0   acquired        A
# 1  operating        O
# 2  operating        O
# 3  operating        O
# 4  operating        O

# %% [markdown]
# 18.	How many companies have ‘debt_financing’ above zero?

# %%
df[df.debt_financing > 0]['name'].shape[0]
# Out:
# 4225

# %% [markdown]
# 19.	Create a column ‘homepage’ to store company name from ‘homepage_url’: For example: If url is http://www.waywire.com, name is waywire.

# %%
import re
df.homepage_url.apply(lambda x: re.sub("(http://www.|.com)", '', str(x))).head()
# Out:
# 0              waywire
# 1    http://enjoyandtv
# 2    rockyourpaper.org
# 3       InTouchNetwork
# 4                  nan
# Name: homepage_url, dtype: object

# %% [markdown]
# 20.	Find the count of companies in each of the markets.

# %%
df.groupby('market')['name'].count()
# Out:
# market
# 3D               25
# 3D Printing       9
# 3D Technology     8
# Accounting       18
# Ad Targeting     13
#                  ..
# iOS              48
# iPad             29
# iPhone           69
# iPod Touch        3
# mHealth           8
# Name: name, Length: 753, dtype: int64

# %% [markdown]
# 21.	Find the count of companies in each of the markets and store the new column ‘cnt_name’ in the original dataframe.

# %%
df['cnt_name']=df.groupby('market')['name'].transform('count')
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#    funding_total_usd     status country_code state_code         region  \
# 0          1750000.0   acquired          USA         NY  New York City
# 1          4000000.0  operating          USA         CA    Los Angeles
# 2            40000.0  operating          EST        NaN        Tallinn
# 3          1500000.0  operating          GBR        NaN         London
# 4            60000.0  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    categcategory_list_count  category_list_count status_E  cnt_name
# 0                     45477                    4        A     378.0
# 1                     45477                    1        O    1182.0
# 2                     45477                    2        O      69.0
# 3                     45477                   10        O      43.0
# 4                     45477                    3        O      21.0

# %% [markdown]
# 22.	Rename ' funding_total_usd ' to 'funding_total_usd'

# %%
df.rename(columns={'fundings_total_usd':'fundingss_total_usd'})
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                 |Publishing|Education|           Publishing
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# 4                          |Tourism|Entertainment|Games|              Tourism
# ...                                                  ...                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#        funding_total_usd     status country_code state_code         region  \
# 0              1750000.0   acquired          USA         NY  New York City
# 1              4000000.0  operating          USA         CA    Los Angeles
# 2                40000.0  operating          EST        NaN        Tallinn
# 3              1500000.0  operating          GBR        NaN         London
# 4                60000.0  operating          USA         TX         Dallas
# ...                  ...        ...          ...        ...            ...
# 49433           320000.0  operating          GBR        NaN         London
# 49434          1587301.0  operating          CHN        NaN        Beijing
# 49435            97398.0  operating          HRV        NaN          Split
# 49436          9300000.0  operating          NaN        NaN            NaN
# 49437         45000000.0  operating          USA         NY  New York City
#
#               city  funding_rounds  founded_year  debt_financing  grant  \
# 0         New York               1        2012.0               0      0
# 1      Los Angeles               2           NaN               0      0
# 2          Tallinn               1        2012.0               0      0
# 3           London               1        2011.0               0      0
# 4       Fort Worth               2        2014.0               0      0
# ...            ...             ...           ...             ...    ...
# 49433       London               1        2013.0               0      0
# 49434      Beijing               1           NaN               0      0
# 49435        Split               5        2012.0               0      0
# 49436          NaN               1           NaN               0      0
# 49437     New York               4        1999.0        17000000      0
#
#        categcategory_list_count  category_list_count status_E  cnt_name
# 0                         45477                    4        A     378.0
# 1                         45477                    1        O    1182.0
# 2                         45477                    2        O      69.0
# 3                         45477                   10        O      43.0
# 4                         45477                    3        O      21.0
# ...                         ...                  ...      ...       ...
# 49433                     45477                    6        O     863.0
# 49434                     45477                    1        O    1280.0
# 49435                     45477                    4        O     103.0
# 49436                     45477                    1        O    1182.0
# 49437                     45477                    1        O    1280.0
#
# [49438 rows x 18 columns]

# %% [markdown]
# 23.	Fill missing values in column ‘city’ with ‘other_city’

# %%
df.city.fillna('other_city', inplace = True)
df.city.isnull().sum()
# Out:
# 0

# %% [markdown]
# 24.	For each row in column ‘funding_total_usd’, calculate actual – average value for each group ‘city’

# %%
df.groupby('city')['funding_total_usd'].transform(lambda x : x -np.mean(x)).head()
# Out:
# 0   -2.444616e+07
# 1   -7.234447e+06
# 2   -1.723232e+06
# 3   -6.784773e+06
# 4   -3.522942e+07
# Name: funding_total_usd, dtype: float64

# %% [markdown]
# 25.	Normalize ‘‘funding_total_usd’ at country level.

# %%
 #print(min(df.funding_total_usd))
#print(max(df.funding_total_usd))
df.country_code.fillna('other_country', inplace = True)
df.groupby('country_code')['funding_total_usd'].transform(lambda x: (x - min(x))/ (max(x) - min(x)))
# Out:
# 0        0.000058
# 1        0.000133
# 2        0.002106
# 3        0.002381
# 4        0.000002
#            ...
# 49433    0.000508
# 49434    0.000496
# 49435    0.064932
# 49436    0.008809
# 49437    0.001496
# Name: funding_total_usd, Length: 49438, dtype: float64

# %% [markdown]
# 26.	What is the average ‘funding_total_usd’ for each city?

# %%
df.groupby('city')['funding_total_usd'].mean()
# Out:
# city
# 6 October City    1.450000e+05
# A Coruña          1.236930e+06
# Aachen            6.448845e+06
# Aalborg           1.166667e+05
# Aarhus            2.546595e+06
#                       ...
# Évora             0.000000e+00
# Évry              2.212513e+05
# Ísafjörður        4.000000e+06
# Örnsköldsvik      0.000000e+00
# Østerby Havn      8.550000e+05
# Name: funding_total_usd, Length: 4189, dtype: float64

# %% [markdown]
# 27.	Plot histogram/distribution of ‘funding_total_usd’ and provide insights if any.

# %%
fig, ax = plt.subplots(1,2, figsize = (15,4))
ax[0].hist(df.funding_total_usd)
ax[0].set_title('Histogram on raw data')
ax[1].hist(np.log1p(df.funding_total_usd))
ax[1].set_title('Histogram on Log transformed data')
plt.show()

# %% [markdown]
# 28.	What is maximum ‘funding_total_usd’ for each market status?

# %%
df.groupby('market')['funding_total_usd'].max()
# Out:
# market
# 3D                20600000.0
# 3D Printing       22300000.0
# 3D Technology      9140352.0
# Accounting       181625355.0
# Ad Targeting      89000000.0
#                     ...
# iOS               95000000.0
# iPad              14078664.0
# iPhone            30250000.0
# iPod Touch         2638000.0
# mHealth            3300000.0
# Name: funding_total_usd, Length: 753, dtype: float64

# %% [markdown]
# 29.	How many years has it been since each company was founded?

# %%
from datetime import datetime
df['cmpany_age'] = datetime.today().year- df.founded_year 
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#    funding_total_usd     status country_code state_code         region  \
# 0          1750000.0   acquired          USA         NY  New York City
# 1          4000000.0  operating          USA         CA    Los Angeles
# 2            40000.0  operating          EST        NaN        Tallinn
# 3          1500000.0  operating          GBR        NaN         London
# 4            60000.0  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    categcategory_list_count  category_list_count status_E  cnt_name  \
# 0                     45477                    4        A     378.0
# 1                     45477                    1        O    1182.0
# 2                     45477                    2        O      69.0
# 3                     45477                   10        O      43.0
# 4                     45477                    3        O      21.0
#
#    cmpany_age
# 0         9.0
# 1         NaN
# 2         9.0
# 3        10.0
# 4         7.0

# %% [markdown]
# 30.	Visualize ‘grant’ distribution.

# %%
fig, ax = plt.subplots(1,2, figsize = (15,4))
ax[0].hist(df.grant)
ax[0].set_title('Histogram on raw data')
ax[1].hist(np.log1p(df.grant))
ax[1].set_title('Histogram on Log transformed data')
plt.show()

# %% [markdown]
# 31.	Visualize ‘debt_financing’ distribution

# %%
fig, ax = plt.subplots(1,2, figsize = (15,4))
ax[0].hist(df.debt_financing)
ax[0].set_title('Histogram on raw data')
ax[1].hist(np.log1p(df.debt_financing))
ax[1].set_title('Histogram on Log transformed data')
plt.show()

# %% [markdown]
# 32.	Display proportion of companies status

# %%
df.groupby('status')['name'].count()/df.shape[0]*100
# Out:
# status
# acquired      7.467940
# closed        5.263158
# operating    84.609005
# Name: name, dtype: float64

# %% [markdown]
# 33.	How many US states are available?

# %%
df[df.country_code == 'USA']['state_code'].nunique()
# Out:
# 51

# %% [markdown]
# 34.	create column ‘cmt_address’ by joining country code, state code, region and city.

# %%
df['cmt_address']= df.country_code + '_' +df.state_code + '_' + df.region
df
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                 |Publishing|Education|           Publishing
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# 4                          |Tourism|Entertainment|Games|              Tourism
# ...                                                  ...                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#        funding_total_usd     status   country_code state_code         region  \
# 0              1750000.0   acquired            USA         NY  New York City
# 1              4000000.0  operating            USA         CA    Los Angeles
# 2                40000.0  operating            EST        NaN        Tallinn
# 3              1500000.0  operating            GBR        NaN         London
# 4                60000.0  operating            USA         TX         Dallas
# ...                  ...        ...            ...        ...            ...
# 49433           320000.0  operating            GBR        NaN         London
# 49434          1587301.0  operating            CHN        NaN        Beijing
# 49435            97398.0  operating            HRV        NaN          Split
# 49436          9300000.0  operating  other_country        NaN            NaN
# 49437         45000000.0  operating            USA         NY  New York City
#
#               city  funding_rounds  founded_year  debt_financing  grant  \
# 0         New York               1        2012.0               0      0
# 1      Los Angeles               2           NaN               0      0
# 2          Tallinn               1        2012.0               0      0
# 3           London               1        2011.0               0      0
# 4       Fort Worth               2        2014.0               0      0
# ...            ...             ...           ...             ...    ...
# 49433       London               1        2013.0               0      0
# 49434      Beijing               1           NaN               0      0
# 49435        Split               5        2012.0               0      0
# 49436   other_city               1           NaN               0      0
# 49437     New York               4        1999.0        17000000      0
#
#        categcategory_list_count  category_list_count status_E  cnt_name  \
# 0                         45477                    4        A     378.0
# 1                         45477                    1        O    1182.0
# 2                         45477                    2        O      69.0
# 3                         45477                   10        O      43.0
# 4                         45477                    3        O      21.0
# ...                         ...                  ...      ...       ...
# 49433                     45477                    6        O     863.0
# 49434                     45477                    1        O    1280.0
# 49435                     45477                    4        O     103.0
# 49436                     45477                    1        O    1182.0
# 49437                     45477                    1        O    1280.0
#
#        cmpany_age           cmt_address
# 0             9.0  USA_NY_New York City
# 1             NaN    USA_CA_Los Angeles
# 2             9.0                   NaN
# 3            10.0                   NaN
# 4             7.0         USA_TX_Dallas
# ...           ...                   ...
# 49433         8.0                   NaN
# 49434         NaN                   NaN
# 49435         9.0                   NaN
# 49436         NaN                   NaN
# 49437        22.0  USA_NY_New York City
#
# [49438 rows x 20 columns]

# %% [markdown]
# 35.	select columns with underscore in their names.

# %%
df.filter(regex='_').head()
# Out:
#                     homepage_url  \
# 0         http://www.waywire.com
# 1          http://enjoyandtv.com
# 2   http://www.rockyourpaper.org
# 3  http://www.InTouchNetwork.com
# 4                            NaN
#
#                                        category_list  funding_total_usd  \
# 0         |Entertainment|Politics|Social Media|News|          1750000.0
# 1                                            |Games|          4000000.0
# 2                             |Publishing|Education|            40000.0
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...          1500000.0
# 4                      |Tourism|Entertainment|Games|            60000.0
#
#   country_code state_code  funding_rounds  founded_year  debt_financing  \
# 0          USA         NY               1        2012.0               0
# 1          USA         CA               2           NaN               0
# 2          EST        NaN               1        2012.0               0
# 3          GBR        NaN               1        2011.0               0
# 4          USA         TX               2        2014.0               0
#
#    categcategory_list_count  category_list_count status_E  cnt_name  \
# 0                     45477                    4        A     378.0
# 1                     45477                    1        O    1182.0
# 2                     45477                    2        O      69.0
# 3                     45477                   10        O      43.0
# 4                     45477                    3        O      21.0
#
#    cmpany_age           cmt_address
# 0         9.0  USA_NY_New York City
# 1         NaN    USA_CA_Los Angeles
# 2         9.0                   NaN
# 3        10.0                   NaN
# 4         7.0         USA_TX_Dallas
